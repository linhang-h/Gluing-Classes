# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from Gluing import *

# %%
itinerary(alpha, 20)
# Out:
# 'LRLLLLLRRRRLLLLRRRLR'

# %%
C = GluingSet('LR**L')

# %%
C.plot()

# %%
C.star()
C.plot()
