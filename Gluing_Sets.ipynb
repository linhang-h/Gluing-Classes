# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from Gluing import *

# %% [markdown]
# ### **Finding the gluing set associated with a word**

# %%
C = GluingSet('*R**LL')
C.plot()

# %%
# Out:
# Gluing Set: *R**LL
# Gluing Links: LRLRLL RRLRLL LRRRLL RRRRLL LRLLLL RRLLLL LRRLLL RRRLLL

# %%
C.star()
C.plot(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 C.star()
# ----> 2 C.plot(True)
#
# File ~/Desktop/Module Materials/Research Projects/Gluing Classes/Gluing.py:377, in GluingSet.plot(self, save)
#     375 ax.plot([radius*math.cos(2*math.pi*star1),radius*math.cos(2*math.pi*star2)], [radius*math.sin(2*math.pi*star1),radius*math.sin(2*math.pi*star2)], linewidth=2, linestyle = '--', c='red')
#     376 if save:
# --> 377     plt.savefig(os.getcwd() + '/Gluing_set.png', format="png", bbox_inches = 'tight')
#     378 plt.show()
#
# NameError: name 'os' is not defined

# %% [markdown]
# ### **Pullback a gluing link**

# %%
C = GluingSet('LR**L')
C.plot()

# %%
C.star()
print(C)
C.plot()
# Out:
# Gluing Set: *LR**L
# Gluing Links: LLRR*L RLRR*L *LRL*L

# %%
C.add('**')
print(C)
C.plot()
# Out:
# Gluing Set: ***LR**L
# Gluing Links: LRLLRR*L RRLLRR*L LLLLRR*L RLLLRR*L LRRLRR*L RRRLRR*L LLRLRR*L RLRLRR*L LR*LRL*L RR*LRL*L LL*LRL*L RL*LRL*L

# %% [markdown]
# ### **A legal word corresponds to a single link**

# %%
w = 'L*L*RL'

# %%
C = GluingSet(w)
C.plot()

# %%
v = legalize('LRLLRL')
v
# Out:
# 'LR*L*L'

# %%
C1 = GluingSet(v)
C1.plot()

# %% [markdown]
# ### **Duplicating intervals**

# %%
w = 'LRLLLLLRRLLRLRLLLLLRRLLRR'
duplicating(w)

# %% [markdown]
# ### **Boundary of GCSes are regular**

# %%
w = 'LRLLLLRLLRL'
v = legalize(w)
C = GluingLink(w)
C1 = GluingLink(v)
print(C)
print(C1)
# Out:
# Gluing Link: LRLLLLRLLRL
# Leaves: LRLLLLRLLR* LRLLLLRLL* LRLLLLR*
# Gluing Link: LRLL*LR*L*L
# Leaves: LRLLLLRLLL* LRLLRLRLLL* LRLLLLRRLL* LRLLRLRRLL* LRLLLLRLLR* LRLLRLRLLR* LRLLLLRRLR* LRLLRLRRLR*

# %%
C = GluingSet('LRLLLLRRRR*LLLR')

# %%
for link in C.links:
    print(link)
# Out:
# Gluing Link: LRLLLLRRRRLLLLR
# Leaves: LRLLLLRRRRLLLL* LRLLLLRRRRLL*
# Gluing Link: LRLLLLRRRRRLLLR
# Leaves: LRLLLLRRRRRLLL* LRLLLLRRRRRL*

# %%
x = 0.23
n = 10

# %%
x*(2**(n-1)) % 1
# Out:
# 0.7600000000000051

# %%
C = C_n.right()
C.plot()
