# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from Gluing import *

# %%
C = GluingSet('*R**LL')

# %%
C.plot()

# %%
D = C.links[0]
print(D)
# Out:
# Gluing Link: LRLRLL
# Leaves: LRLRL* LRLR* L*

# %%
D.plot()

# %%
word = "LRLLLLR"
legal_word = legalize(word)
legal_word
# Out:
# 'LRLL*LR'

# %%
C1 = GluingLink(legal_word)
print(C1)
# Out:
# Gluing Link: LRLL*LR
# Leaves: LRLLLL* LRLLRL*

# %%
C1.plot()

# %%
C = GluingLink("L")
C.plot()

# %%
D  = C.split()
D.plot()
